# %% [markdown]
# ## Intalacion de la libreria de OpenStreetMap

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.0.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: geopandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.0.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.4.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.32.3)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.0.6)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from geopandas>=1.0->osmnx) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=1.0->osmnx) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas>=1.0->osmnx) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->osmnx) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->osmnx) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.16.0)
# Downloading osmnx-2.0.0-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.0.0

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.10/dist-packages (1.1.1)

# %% [markdown]
# ## Librerias importantes para el desarrollo del Proyecto EcoRouteX

# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
import os
import geopandas as gpd
from shapely.geometry import box, Point, LineString
import pandas as pd
import csv
import numpy
import folium
import pymysql
import json

# %% [markdown]
# ## Eleccion del distrito (Para este proyecto solo se trabaja con San Borja)

# %%
# Descargar la red de calles de San Borja
place = "San Borja, Peru" # Podemos cambiar el distrito a voluntad
sb = ox.graph_from_place(place, network_type="drive")

# %% [markdown]
# # Enviar la ruta a la base de datos

# %%
def subir_mapa(m, recorrido, sector, distancia_total, tiempo_total, orden):
  # Conexión a la base de datos
  conexion = pymysql.connect(
          host='junction.proxy.rlwy.net',
          user='root',
          password='GUGPuaDajYUZbtXKVvqgtmeWIeRrYuwM',
          database='EcoRoutex',
          port=42752
  )

  cursor = conexion.cursor()

  # Obtener el ID de un camión en espera
  query_camion = "SELECT id_camion FROM camion WHERE accion = 'Esperando' LIMIT 1"
  cursor.execute(query_camion)
  camion_id = cursor.fetchone()[0]  # Obtiene el primer camión en estado 'Esperando'

  # Convertir el mapa a HTML
  # Guardar el mapa como archivo HTML
  m.save("mapa.html")

  # Leer el contenido del archivo HTML
  with open("mapa.html", "r") as file:
      mapa_html = file.read()

  # Insertar en la tabla ruta
  query_insert = """
  INSERT INTO ruta (puntos, camion_id, sector, activo, mapa, distancia, tiempo, orden)
  VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
  """
  valores = (json.dumps(recorrido), camion_id, str(sector), 1, mapa_html, round(distancia_total, 4), round(tiempo_total, 4), orden)

  cursor.execute(query_insert, valores)
  conexion.commit()

  # Cerrar la conexión
  cursor.close()
  conexion.close()

# %% [markdown]
# # Visualización de la ruta que se debe seguir

# %%
# Función para obtener las coordenadas de un nodo en el grafo de OSMnx
def obtener_coordenadas_de_nodo(G, nodo_id):
    """
    Dada una ID de nodo de OpenStreetMap, obtiene las coordenadas geográficas más cercanas en el grafo de OSMnx.
    """
    coords = ox.graph_to_gdfs(G, nodes=True, edges=False).loc[nodo_id, ['y', 'x']]  # 'y' es lat, 'x' es lon
    return coords['y'], coords['x']

# Paso 2: Obtener las coordenadas de los nodos del recorrido
def mapa(recorrido, sector, distancia_total, tiempo_total, orden):
  nodos_con_coordenadas = {}
  for nodo in recorrido:
      try:
          lat, lon = obtener_coordenadas_de_nodo(sb, nodo)
          nodos_con_coordenadas[nodo] = (lat, lon)
      except KeyError:
          print(f"Nodo {nodo} no encontrado en el grafo de OSMnx.")

  # Paso 4: Encontrar los nodos más cercanos en el grafo a las coordenadas dadas
  def obtener_nodo_mas_cercano(G, lat, lon):
      """
      Dado un par de coordenadas (lat, lon), devuelve el ID del nodo más cercano en el grafo de OSMnx.
      """
      node = ox.distance.nearest_nodes(G, X=lon, Y=lat)  # 'X' es longitud, 'Y' es latitud
      return node

  # Paso 5: Calcular la ruta más corta entre los nodos seleccionados
  rutas = []
  for i in range(len(nodos_con_coordenadas)-1):
      nodo_origen = nodos_con_coordenadas[recorrido[i]]
      nodo_destino = nodos_con_coordenadas[recorrido[i+1]]

      origen_id = obtener_nodo_mas_cercano(sb, nodo_origen[0], nodo_origen[1])
      destino_id = obtener_nodo_mas_cercano(sb, nodo_destino[0], nodo_destino[1])

      try:
          # Intentamos calcular la ruta más corta usando NetworkX
          route = nx.shortest_path(sb, source=origen_id, target=destino_id, weight='length')
          rutas.append(route)
      except nx.NetworkXNoPath:
          # Si no hay ruta entre los nodos, imprimimos un mensaje y continuamos con el siguiente par de nodos
          print(f"No se encontró una ruta entre el nodo {recorrido[i]} y el nodo {recorrido[i+1]}. Intentando con el siguiente par de nodos.")
          continue  # Continúa con el siguiente par de nodos

  # Paso 6: Crear un mapa interactivo con Folium para visualizar la ruta
  m = folium.Map(location=[-12.09755, -76.99521], zoom_start=13)

  # Paso 7: Visualizar las rutas calculadas en el mapa
  for route in rutas:
      # Convertir la ruta de nodos a coordenadas
      route_coords = [(sb.nodes[node]['y'], sb.nodes[node]['x']) for node in route]

      # Crear una línea de la ruta
      folium.PolyLine(route_coords, color="blue", weight=4).add_to(m)

  # Paso 8: Resaltar los nodos del recorrido con marcadores y círculos
  for nodo, coords in nodos_con_coordenadas.items():
      lat, lon = coords

      # Colocar un marcador con un color personalizado para los nodos del recorrido
      folium.Marker(
          location=[lat, lon],
          popup=f"Nodo ID: {nodo}",
          icon=folium.Icon(color='red', icon='info-sign')  # Puedes cambiar el icono o color
      ).add_to(m)

      # Añadir un círculo alrededor de los nodos para hacerlos más visibles
      folium.Circle(
          location=[lat, lon],
          radius=50,  # Tamaño del círculo
          color='red',
          fill=True,
          fill_color='red'
      ).add_to(m)
  subir_mapa(m, recorrido, sector, distancia_total, tiempo_total, orden)

# %% [markdown]
# # Codigo de **EcoRouteX** (como resultado se obtiene el recorrido que debe seguir el camión)

# %%
def obtener_datos_contenedor_activo_sector(sector_determinado):
    # Conexión a la base de datos
    connection = pymysql.connect(
        host='junction.proxy.rlwy.net',
        user='root',
        password='GUGPuaDajYUZbtXKVvqgtmeWIeRrYuwM',
        database='EcoRoutex',
        port=42752
    )

    try:
        with connection.cursor() as cursor:
            # Realizar la consulta SQL con las condiciones para activo y sector
            sql_select = "SELECT * FROM contenedor WHERE activo = '1' AND sector = %s"

            cursor.execute(sql_select, (sector_determinado,))

            # Obtener todos los resultados
            resultados = cursor.fetchall()

            # Obtener los nombres de las columnas
            columnas = [desc[0] for desc in cursor.description]

            # Convertir los resultados a un DataFrame de pandas
            df_contenedor = pd.DataFrame(resultados, columns=columnas)

        with connection.cursor() as cursor:
            # Consulta SQL para seleccionar solo las filas donde N_nodo_origen pertenece al sector
            # Aquí asumimos que existe una relación entre `N_nodo_origen` y el sector
            sql_select = """
                SELECT *
                FROM tiempos
                WHERE N_nodo_origen IN (
                    SELECT N_nodo
                    FROM contenedor
                    WHERE sector = %s AND activo = '1'
                )
            """
            cursor.execute(sql_select, (sector_determinado,))

            # Obtener todos los resultados
            resultados = cursor.fetchall()

            # Obtener los nombres de las columnas
            columnas = [desc[0] for desc in cursor.description]

            # Convertir los resultados a un DataFrame de pandas
            df_tiempos = pd.DataFrame(resultados, columns=columnas)

        return (df_contenedor, df_tiempos)

    except pymysql.MySQLError as e:
        print(f"Error al realizar la consulta: {e}")
        return None

    finally:
        connection.close()

# %%
def crear_diccionario_distancias_tiempos(datos_unidos_df):
    distancias_tiempos = {}
    for _, row in datos_unidos_df.iterrows():
        origen = row['N_nodo_origen']
        destino = row['N_nodo_destino']
        distancia = float(row['distancia'])
        tiempo = float(row['tiempo'])
        if origen not in distancias_tiempos:
            distancias_tiempos[origen] = {}
        distancias_tiempos[origen][destino] = {'distancia': distancia, 'tiempo': tiempo}
    return distancias_tiempos

def normalizar(valor, max_valor, min_valor):
    if max_valor == min_valor:
        return 0
    return (valor - min_valor) / (max_valor - min_valor)

def seleccionar_siguiente_nodo(nodo_actual, distancias_tiempos, capacidades, visitados, capacidad_restante):
    candidatos = []
    max_capacidad = max(capacidades.values())
    min_capacidad = min(capacidades.values())
    print(f"\nAnalizando opciones desde el nodo {nodo_actual}...")

    # Filtrar valores válidos (diferentes de 1000000000.00) para normalización
    valores_distancia = [d['distancia'] for d in distancias_tiempos[nodo_actual].values()
                        if d['distancia'] != 1000000000.00]
    valores_tiempo = [d['tiempo'] for d in distancias_tiempos[nodo_actual].values()
                     if d['tiempo'] != 1000000000.00]

    # Si no hay valores válidos, usar valores por defecto
    if not valores_distancia or not valores_tiempo:
        print("  No hay conexiones válidas desde este nodo.")
        return None, 0, 0, 0

    max_distancia = max(valores_distancia)
    min_distancia = min(valores_distancia)
    max_tiempo = max(valores_tiempo)
    min_tiempo = min(valores_tiempo)

    for nodo_destino, datos in distancias_tiempos[nodo_actual].items():
        distancia = datos['distancia']
        tiempo = datos['tiempo']

        # Saltar nodos con valores de 1000000000.00
        if (distancia == 1000000000.00 or tiempo == 1000000000.00 or
            nodo_destino in visitados or nodo_destino == nodo_actual or
            capacidades[nodo_destino] <= 0):
            continue

        distancia_normalizada = normalizar(distancia, max_distancia, min_distancia)
        tiempo_normalizado = normalizar(tiempo, max_tiempo, min_tiempo)
        capacidad_normalizada = normalizar(capacidades[nodo_destino], max_capacidad, min_capacidad)

        prioridad = (0.3 * capacidad_normalizada) + (0.5 * (1 - distancia_normalizada)) + (0.2 * (1 - tiempo_normalizado))
        print(f"  Considerando nodo {nodo_destino} con capacidad {capacidades[nodo_destino]}, "
              f"distancia {distancia:.2f} metros y tiempo {tiempo:.2f} minutos. Prioridad: {prioridad:.3f}")

        if capacidades[nodo_destino] <= capacidad_restante:
            candidatos.append((prioridad, nodo_destino, distancia, tiempo))

    if candidatos:
        candidatos.sort(reverse=True, key=lambda x: x[0])
        mejor_opcion = candidatos[0]
        print(f"  Seleccionado nodo {mejor_opcion[1]} con prioridad {mejor_opcion[0]:.2f}, "
              f"capacidad {capacidades[mejor_opcion[1]]}, distancia {mejor_opcion[2]:.2f} metros "
              f"y tiempo {mejor_opcion[3]:.2f} minutos.")
        return mejor_opcion[1], capacidades[mejor_opcion[1]], mejor_opcion[2], mejor_opcion[3]

    print("  No hay más nodos disponibles para visitar o todos exceden la capacidad restante del camión.")
    return None, 0, 0, 0

def recorrido_priorizado(sector):
    df_resultados, datos_unidos_df = obtener_datos_contenedor_activo_sector(sector)
    capacidades_nodos = dict(zip(df_resultados['N_nodo'], df_resultados['capacidad']))
    distancias_tiempos = crear_diccionario_distancias_tiempos(datos_unidos_df)
    nodos_sector = datos_unidos_df['N_nodo_origen'].unique()
    print(nodos_sector)
    capacidades = {nodo: capacidades_nodos[nodo] for nodo in nodos_sector if nodo in capacidades_nodos}
    nodo_inicial = list(capacidades.keys())[0]
    nodo_actual = nodo_inicial
    visitados = set([nodo_actual])
    recorrido = [int(nodo_actual)]
    recorrido_total = [int(nodo_actual)]
    capacidad_restante = 10000
    distancia_total = 0
    tiempo_total = 0
    orden = 0
    print(f"Iniciando en el nodo {nodo_actual}. Capacidad restante: {capacidad_restante}")

    while True:
        siguiente_nodo, capacidad_nodo, distancia, tiempo = seleccionar_siguiente_nodo(
            nodo_actual, distancias_tiempos, capacidades, visitados, capacidad_restante)

        if siguiente_nodo is None:
            print("No hay más nodos disponibles para visitar o todos exceden la capacidad restante del camión. "
                  "Finalizando recorrido.")
            break

        visitados.add(siguiente_nodo)
        recorrido_total.append(int(siguiente_nodo))
        recorrido.append(int(siguiente_nodo))
        capacidad_restante -= capacidad_nodo
        distancia_total += distancia
        tiempo_total += tiempo
        orden += 1

        print(f"Moviéndose al nodo {siguiente_nodo} con capacidad {capacidades[siguiente_nodo]}. "
              f"Capacidad restante: {capacidad_restante}. Distancia total: {distancia_total:.2f} metros. "
              f"Tiempo total: {tiempo_total:.2f} minutos.")
        print(recorrido_total)
        nodo_actual = siguiente_nodo

        if capacidad_restante <= 0:
            print("El camión ha alcanzado su capacidad máxima. Finalizando recorrido.")
            break
        mapa(recorrido, sector, distancia, tiempo, orden)
        recorrido.pop(0)

    if nodo_actual != nodo_inicial:
        # Verificar si existe una conexión válida de regreso
        if (distancias_tiempos[nodo_actual][nodo_inicial]['distancia'] != 1000000000.00 and
            distancias_tiempos[nodo_actual][nodo_inicial]['tiempo'] != 1000000000.00):
            distancia_de_regreso = distancias_tiempos[nodo_actual][nodo_inicial]['distancia']
            tiempo_de_regreso = distancias_tiempos[nodo_actual][nodo_inicial]['tiempo']
            distancia_total += distancia_de_regreso
            tiempo_total += tiempo_de_regreso
            recorrido.append(int(nodo_inicial))
            print(f"Regresando al nodo {nodo_inicial} desde el nodo {nodo_actual}. "
                  f"Distancia de regreso: {distancia_de_regreso:.2f} metros. "
                  f"Tiempo de regreso: {tiempo_de_regreso:.2f} minutos.")
        else:
            print(f"No existe una conexión válida para regresar al nodo inicial {nodo_inicial} "
                  f"desde el nodo {nodo_actual}.")
    # Preguntar al usuario si desea continuar
    mapa(recorrido_total, sector, distancia_total, tiempo_total, 0)
    print(f"\nRecorrido completo: {recorrido_total}")
    print(f"Distancia total recorrida: {distancia_total:.2f} metros")
    print(f"Tiempo total: {tiempo_total:.2f} minutos")

# %%
# Solicitar el sector para filtrar los nodos
for sector in range(1,5):
  recorrido_priorizado(sector)
# Out:
# ['412529888' '3903819668' '412554073' '412549362' '412554037' '417252102'
#  '417252136' '1273879842' '417252706' '412528235' '1841915508'
#  '3630229215' '417251204' '392151970' '391036814' '412554325' '4354022565'
#  '4170789705' '412529887' '412557563' '9890962282' '417251195' '412554242'
#  '791159897' '326022171' '417251159' '417252572' '3628169609' '412553943'
#  '412554253' '412528242' '4549868556' '1273664820' '417252592' '515494213'
#  '412554319' '417252214' '316625042' '9890779746' '412557570' '412557535'
#  '412528255' '412528286' '4351533396' '412529889' '6408227574' '263933849'
#  '3628219077' '412528267' '4042528361' '9890955626']
# Iniciando en el nodo 412529888. Capacidad restante: 10000
#
# Analizando opciones desde el nodo 412529888...
#   Considerando nodo 3903819668 con capacidad 96, distancia 1049.38 metros y tiempo 15.00 minutos. Prioridad: 0.688
#   Considerando nodo 412554073 con capacidad 34, distancia 1545.35 metros y tiempo 17.00 minutos. Prioridad: 0.374
#   Considerando nodo 412549362 con capacidad 14, distancia 548.32 metros y tiempo 6.00 minutos. Prioridad: 0.609
#   Considerando nodo 412554037 con capacidad 46, distancia 1401.95 metros y tiempo 15.00 minutos. Prioridad: 0.456
#   Considerando nodo 417252102 con capacidad 11, distancia 1764.33 metros y tiempo 23.00 minutos. Prioridad: 0.215
#   Considerando nodo 417252136 con capacidad 51, distancia 1567.51 metros y tiempo 22.00 minutos. Prioridad: 0.388
#   Considerando nodo 1273879842 con capacidad 81, distancia 804.19 metros y tiempo 11.00 minutos. Prioridad: 0.723
#   Considerando nodo 417252706 con capacidad 88, distancia 1337.74 metros y tiempo 18.00 minutos. Prioridad: 0.579
#   Considerando nodo 412528235 con capacidad 94, distancia 723.82 metros y tiempo 11.00 minutos. Prioridad: 0.781
#   Considerando nodo 1841915508 con capacidad 84, distancia 694.71 metros y tiempo 13.00 minutos. Prioridad: 0.744
#   Considerando nodo 3630229215 con capacidad 36, distancia 1225.48 metros y tiempo 16.00 minutos. Prioridad: 0.458
#   Considerando nodo 417251204 con capacidad 41, distancia 1462.84 metros y tiempo 19.00 minutos. Prioridad: 0.401
#   Considerando nodo 392151970 con capacidad 5, distancia 1989.95 metros y tiempo 26.00 minutos. Prioridad: 0.127
#   Considerando nodo 391036814 con capacidad 83, distancia 1494.00 metros y tiempo 16.00 minutos. Prioridad: 0.542
#   Considerando nodo 412554325 con capacidad 56, distancia 1630.47 metros y tiempo 16.00 minutos. Prioridad: 0.429
#   Considerando nodo 4354022565 con capacidad 47, distancia 359.08 metros y tiempo 5.00 minutos. Prioridad: 0.758
#   Considerando nodo 4170789705 con capacidad 38, distancia 1584.17 metros y tiempo 22.00 minutos. Prioridad: 0.345
#   Considerando nodo 412529887 con capacidad 26, distancia 124.74 metros y tiempo 2.00 minutos. Prioridad: 0.766
#   Considerando nodo 412557563 con capacidad 39, distancia 1271.80 metros y tiempo 16.00 minutos. Prioridad: 0.457
#   Considerando nodo 9890962282 con capacidad 17, distancia 1862.14 metros y tiempo 25.00 minutos. Prioridad: 0.198
#   Considerando nodo 417251195 con capacidad 49, distancia 2165.33 metros y tiempo 28.00 minutos. Prioridad: 0.209
#   Considerando nodo 412554242 con capacidad 9, distancia 1305.61 metros y tiempo 15.00 minutos. Prioridad: 0.365
#   Considerando nodo 791159897 con capacidad 59, distancia 1761.82 metros y tiempo 17.00 minutos. Prioridad: 0.403
#   Considerando nodo 326022171 con capacidad 70, distancia 416.88 metros y tiempo 6.00 minutos. Prioridad: 0.809
#   Considerando nodo 417251159 con capacidad 86, distancia 1580.99 metros y tiempo 19.00 minutos. Prioridad: 0.512
#   Considerando nodo 417252572 con capacidad 87, distancia 1886.31 metros y tiempo 25.00 minutos. Prioridad: 0.407
#   Considerando nodo 3628169609 con capacidad 77, distancia 1831.23 metros y tiempo 24.00 minutos. Prioridad: 0.396
#   Considerando nodo 412553943 con capacidad 32, distancia 1345.96 metros y tiempo 14.00 minutos. Prioridad: 0.433
#   Considerando nodo 412554253 con capacidad 78, distancia 1142.58 metros y tiempo 14.00 minutos. Prioridad: 0.619
#   Considerando nodo 412528242 con capacidad 88, distancia 454.84 metros y tiempo 6.00 minutos. Prioridad: 0.856
#   Considerando nodo 4549868556 con capacidad 14, distancia 95.15 metros y tiempo 1.00 minutos. Prioridad: 0.743
#   Considerando nodo 1273664820 con capacidad 51, distancia 1059.00 metros y tiempo 14.00 minutos. Prioridad: 0.555
#   Considerando nodo 417252592 con capacidad 16, distancia 1873.48 metros y tiempo 24.00 minutos. Prioridad: 0.199
#   Considerando nodo 515494213 con capacidad 55, distancia 1093.24 metros y tiempo 14.00 minutos. Prioridad: 0.559
#   Considerando nodo 412554319 con capacidad 12, distancia 1532.51 metros y tiempo 17.00 minutos. Prioridad: 0.310
#   Considerando nodo 316625042 con capacidad 21, distancia 1159.68 metros y tiempo 12.00 minutos. Prioridad: 0.454
#   Considerando nodo 9890779746 con capacidad 36, distancia 1553.03 metros y tiempo 21.00 minutos. Prioridad: 0.352
#   Considerando nodo 412557570 con capacidad 31, distancia 1536.10 metros y tiempo 16.00 minutos. Prioridad: 0.374
#   Considerando nodo 412557535 con capacidad 44, distancia 1271.85 metros y tiempo 15.00 minutos. Prioridad: 0.479
#   Considerando nodo 412528255 con capacidad 45, distancia 588.14 metros y tiempo 8.00 minutos. Prioridad: 0.681
#   Considerando nodo 412528286 con capacidad 76, distancia 1258.86 metros y tiempo 15.00 minutos. Prioridad: 0.580
#   Considerando nodo 4351533396 con capacidad 98, distancia 1607.04 metros y tiempo 21.00 minutos. Prioridad: 0.530
#   Considerando nodo 412529889 con capacidad 94, distancia 265.03 metros y tiempo 5.00 minutos. Prioridad: 0.923
#   Considerando nodo 6408227574 con capacidad 66, distancia 1011.13 metros y tiempo 15.00 minutos. Prioridad: 0.605
#   Considerando nodo 263933849 con capacidad 43, distancia 1387.62 metros y tiempo 13.00 minutos. Prioridad: 0.464
#   Considerando nodo 3628219077 con capacidad 38, distancia 1925.15 metros y tiempo 26.00 minutos. Prioridad: 0.242
#   Considerando nodo 412528267 con capacidad 20, distancia 782.72 metros y tiempo 10.00 minutos. Prioridad: 0.548
#   Considerando nodo 4042528361 con capacidad 51, distancia 2339.49 metros y tiempo 31.00 minutos. Prioridad: 0.156
#   Considerando nodo 9890955626 con capacidad 63, distancia 1766.77 metros y tiempo 24.00 minutos. Prioridad: 0.367
#   Seleccionado nodo 412529889 con prioridad 0.92, capacidad 94, distancia 265.03 metros y tiempo 5.00 minutos.
# Moviéndose al nodo 412529889 con capacidad 94. Capacidad restante: 9906. Distancia total: 265.03 metros. Tiempo total: 5.00 minutos.
# [412529888, 412529889]
#
# Analizando opciones desde el nodo 412529889...
#   Considerando nodo 3903819668 con capacidad 96, distancia 876.10 metros y tiempo 12.00 minutos. Prioridad: 0.726
#   Considerando nodo 412554073 con capacidad 34, distancia 1372.08 metros y tiempo 14.00 minutos. Prioridad: 0.402
#   Considerando nodo 412549362 con capacidad 14, distancia 448.44 metros y tiempo 3.00 minutos. Prioridad: 0.647
#   Considerando nodo 412554037 con capacidad 46, distancia 1228.68 metros y tiempo 12.00 minutos. Prioridad: 0.489
#   Considerando nodo 417252102 con capacidad 11, distancia 1591.05 metros y tiempo 20.00 minutos. Prioridad: 0.233
#   Considerando nodo 417252136 con capacidad 51, distancia 1592.60 metros y tiempo 20.00 minutos. Prioridad: 0.355
#   Considerando nodo 1273879842 con capacidad 81, distancia 1009.00 metros y tiempo 15.00 minutos. Prioridad: 0.625
#   Considerando nodo 417252706 con capacidad 88, distancia 1404.32 metros y tiempo 18.00 minutos. Prioridad: 0.529
#   Considerando nodo 412528235 con capacidad 94, distancia 550.55 metros y tiempo 8.00 minutos. Prioridad: 0.829
#   Considerando nodo 1841915508 con capacidad 84, distancia 899.53 metros y tiempo 17.00 minutos. Prioridad: 0.645
#   Considerando nodo 3630229215 con capacidad 36, distancia 1300.36 metros y tiempo 16.00 minutos. Prioridad: 0.410
#   Considerando nodo 417251204 con capacidad 41, distancia 1289.57 metros y tiempo 16.00 minutos. Prioridad: 0.428
#   Considerando nodo 392151970 con capacidad 5, distancia 1993.33 metros y tiempo 26.00 minutos. Prioridad: 0.072
#   Considerando nodo 391036814 con capacidad 83, distancia 1320.73 metros y tiempo 13.00 minutos. Prioridad: 0.572
#   Considerando nodo 412554325 con capacidad 56, distancia 1457.19 metros y tiempo 13.00 minutos. Prioridad: 0.457
#   Considerando nodo 4354022565 con capacidad 47, distancia 320.84 metros y tiempo 3.00 minutos. Prioridad: 0.778
#   Considerando nodo 4170789705 con capacidad 38, distancia 1575.94 metros y tiempo 19.00 minutos. Prioridad: 0.327
#   Considerando nodo 412529887 con capacidad 26, distancia 80.08 metros y tiempo 2.00 minutos. Prioridad: 0.780
#   Considerando nodo 412557563 con capacidad 39, distancia 1098.53 metros y tiempo 13.00 minutos. Prioridad: 0.491
#   Considerando nodo 9890962282 con capacidad 17, distancia 1688.87 metros y tiempo 22.00 minutos. Prioridad: 0.213
#   Considerando nodo 417251195 con capacidad 49, distancia 1992.05 metros y tiempo 25.00 minutos. Prioridad: 0.215
#   Considerando nodo 412554242 con capacidad 9, distancia 1132.33 metros y tiempo 12.00 minutos. Prioridad: 0.398
#   Considerando nodo 791159897 con capacidad 59, distancia 1588.54 metros y tiempo 14.00 minutos. Prioridad: 0.427
#   Considerando nodo 326022171 con capacidad 70, distancia 243.60 metros y tiempo 3.00 minutos. Prioridad: 0.867
#   Considerando nodo 417251159 con capacidad 86, distancia 1407.72 metros y tiempo 16.00 minutos. Prioridad: 0.537
#   Considerando nodo 417252572 con capacidad 87, distancia 1889.69 metros y tiempo 25.00 minutos. Prioridad: 0.356
#   Considerando nodo 3628169609 con capacidad 77, distancia 1709.34 metros y tiempo 22.00 minutos. Prioridad: 0.391
#   Considerando nodo 412553943 con capacidad 32, distancia 1172.69 metros y tiempo 11.00 minutos. Prioridad: 0.467
#   Considerando nodo 412554253 con capacidad 78, distancia 969.30 metros y tiempo 11.00 minutos. Prioridad: 0.656
#   Considerando nodo 412528242 con capacidad 88, distancia 354.97 metros y tiempo 3.00 minutos. Prioridad: 0.896
#   Considerando nodo 4549868556 con capacidad 14, distancia 109.66 metros y tiempo 3.00 minutos. Prioridad: 0.728
#   Considerando nodo 1273664820 con capacidad 51, distancia 1263.82 metros y tiempo 17.00 minutos. Prioridad: 0.457
#   Considerando nodo 417252592 con capacidad 16, distancia 1700.20 metros y tiempo 21.00 minutos. Prioridad: 0.215
#   Considerando nodo 515494213 con capacidad 55, distancia 1298.05 metros y tiempo 18.00 minutos. Prioridad: 0.453
#   Considerando nodo 412554319 con capacidad 12, distancia 1359.23 metros y tiempo 14.00 minutos. Prioridad: 0.338
#   Considerando nodo 316625042 con capacidad 21, distancia 1059.81 metros y tiempo 9.00 minutos. Prioridad: 0.476
#   Considerando nodo 9890779746 con capacidad 36, distancia 1619.62 metros y tiempo 21.00 minutos. Prioridad: 0.295
#   Considerando nodo 412557570 con capacidad 31, distancia 1362.83 metros y tiempo 13.00 minutos. Prioridad: 0.403
#   Considerando nodo 412557535 con capacidad 44, distancia 1098.57 metros y tiempo 12.00 minutos. Prioridad: 0.514
#   Considerando nodo 412528255 con capacidad 45, distancia 488.27 metros y tiempo 5.00 minutos. Prioridad: 0.717
#   Considerando nodo 412528286 con capacidad 76, distancia 1085.59 metros y tiempo 12.00 minutos. Prioridad: 0.615
#   Considerando nodo 4351533396 con capacidad 98, distancia 1673.62 metros y tiempo 21.00 minutos. Prioridad: 0.472
#   Considerando nodo 6408227574 con capacidad 66, distancia 1054.04 metros y tiempo 16.00 minutos. Prioridad: 0.561
#   Considerando nodo 263933849 con capacidad 43, distancia 1287.75 metros y tiempo 11.00 minutos. Prioridad: 0.473
#   Considerando nodo 3628219077 con capacidad 38, distancia 1850.85 metros y tiempo 25.00 minutos. Prioridad: 0.215
#   Considerando nodo 412528267 con capacidad 20, distancia 609.44 metros y tiempo 7.00 minutos. Prioridad: 0.596
#   Considerando nodo 4042528361 con capacidad 51, distancia 2166.22 metros y tiempo 28.00 minutos. Prioridad: 0.156
#   Considerando nodo 9890955626 con capacidad 63, distancia 1833.36 metros y tiempo 24.00 minutos. Prioridad: 0.303
#   Seleccionado nodo 412528242 con prioridad 0.90, capacidad 88, distancia 354.97 metros y tiempo 3.00 minutos.
# Moviéndose al nodo 412528242 con capacidad 88. Capacidad restante: 9818. Distancia total: 619.99 metros. Tiempo total: 8.00 minutos.
# [412529888, 412529889, 412528242]
#
# Analizando opciones desde el nodo 412528242...
#   Considerando nodo 3903819668 con capacidad 96, distancia 841.10 metros y tiempo 9.00 minutos. Prioridad: 0.756
#   Considerando nodo 412554073 con capacidad 34, distancia 1332.00 metros y tiempo 11.00 minutos. Prioridad: 0.426
#   Considerando nodo 412549362 con capacidad 14, distancia 267.99 metros y tiempo 3.00 minutos. Prioridad: 0.700
#   Considerando nodo 412554037 con capacidad 46, distancia 1188.60 metros y tiempo 9.00 minutos. Prioridad: 0.516
#   Considerando nodo 417252102 con capacidad 11, distancia 1556.05 metros y tiempo 17.00 minutos. Prioridad: 0.247
#   Considerando nodo 417252136 con capacidad 51, distancia 1557.59 metros y tiempo 17.00 minutos. Prioridad: 0.369
#   Considerando nodo 1273879842 con capacidad 81, distancia 1259.03 metros y tiempo 17.00 minutos. Prioridad: 0.536
#   Considerando nodo 417252706 con capacidad 88, distancia 1369.32 metros y tiempo 15.00 minutos. Prioridad: 0.547
#   Considerando nodo 412528235 con capacidad 94, distancia 515.54 metros y tiempo 5.00 minutos. Prioridad: 0.866
#   Considerando nodo 1841915508 con capacidad 84, distancia 1149.55 metros y tiempo 15.00 minutos. Prioridad: 0.590
#   Considerando nodo 3630229215 con capacidad 36, distancia 1265.35 metros y tiempo 13.00 minutos. Prioridad: 0.431
#   Considerando nodo 417251204 con capacidad 41, distancia 1254.56 metros y tiempo 13.00 minutos. Prioridad: 0.449
#   Considerando nodo 392151970 con capacidad 5, distancia 1958.32 metros y tiempo 23.00 minutos. Prioridad: 0.076
#   Considerando nodo 391036814 con capacidad 83, distancia 1280.65 metros y tiempo 10.00 minutos. Prioridad: 0.597
#   Considerando nodo 412554325 con capacidad 56, distancia 1207.70 metros y tiempo 10.00 minutos. Prioridad: 0.533
#   Considerando nodo 4354022565 con capacidad 47, distancia 381.04 metros y tiempo 4.00 minutos. Prioridad: 0.764
#   Considerando nodo 4170789705 con capacidad 38, distancia 1540.94 metros y tiempo 16.00 minutos. Prioridad: 0.342
#   Considerando nodo 412529887 con capacidad 26, distancia 371.27 metros y tiempo 5.00 minutos. Prioridad: 0.694
#   Considerando nodo 412557563 con capacidad 39, distancia 1058.45 metros y tiempo 10.00 minutos. Prioridad: 0.518
#   Considerando nodo 9890962282 con capacidad 17, distancia 1653.86 metros y tiempo 19.00 minutos. Prioridad: 0.224
#   Considerando nodo 417251195 con capacidad 49, distancia 1957.05 metros y tiempo 22.00 minutos. Prioridad: 0.220
#   Considerando nodo 412554242 con capacidad 9, distancia 1092.25 metros y tiempo 9.00 minutos. Prioridad: 0.427
#   Considerando nodo 791159897 con capacidad 59, distancia 1548.46 metros y tiempo 11.00 minutos. Prioridad: 0.448
#   Considerando nodo 326022171 con capacidad 70, distancia 598.57 metros y tiempo 6.00 minutos. Prioridad: 0.763
#   Considerando nodo 417251159 con capacidad 86, distancia 1367.64 metros y tiempo 13.00 minutos. Prioridad: 0.559
#   Considerando nodo 417252572 con capacidad 87, distancia 1854.68 metros y tiempo 22.00 minutos. Prioridad: 0.362
#   Considerando nodo 3628169609 con capacidad 77, distancia 1674.34 metros y tiempo 19.00 minutos. Prioridad: 0.402
#   Considerando nodo 412553943 con capacidad 32, distancia 1132.61 metros y tiempo 8.00 minutos. Prioridad: 0.496
#   Considerando nodo 412554253 con capacidad 78, distancia 929.22 metros y tiempo 8.00 minutos. Prioridad: 0.687
#   Considerando nodo 4549868556 con capacidad 14, distancia 359.69 metros y tiempo 5.00 minutos. Prioridad: 0.660
#   Considerando nodo 1273664820 con capacidad 51, distancia 1427.90 metros y tiempo 14.00 minutos. Prioridad: 0.428
#   Considerando nodo 417252592 con capacidad 16, distancia 1665.20 metros y tiempo 18.00 minutos. Prioridad: 0.226
#   Considerando nodo 515494213 con capacidad 55, distancia 1548.08 metros y tiempo 16.00 minutos. Prioridad: 0.393
#   Considerando nodo 412554319 con capacidad 12, distancia 1274.32 metros y tiempo 11.00 minutos. Prioridad: 0.373
#   Considerando nodo 316625042 con capacidad 21, distancia 704.84 metros y tiempo 6.00 minutos. Prioridad: 0.586
#   Considerando nodo 9890779746 con capacidad 36, distancia 1584.61 metros y tiempo 18.00 minutos. Prioridad: 0.308
#   Considerando nodo 412557570 con capacidad 31, distancia 1322.75 metros y tiempo 10.00 minutos. Prioridad: 0.428
#   Considerando nodo 412557535 con capacidad 44, distancia 1058.49 metros y tiempo 9.00 minutos. Prioridad: 0.542
#   Considerando nodo 412528255 con capacidad 45, distancia 133.30 metros y tiempo 2.00 minutos. Prioridad: 0.838
#   Considerando nodo 412528286 con capacidad 76, distancia 1045.51 metros y tiempo 9.00 minutos. Prioridad: 0.643
#   Considerando nodo 4351533396 con capacidad 98, distancia 1638.62 metros y tiempo 18.00 minutos. Prioridad: 0.484
#   Considerando nodo 6408227574 con capacidad 66, distancia 1019.04 metros y tiempo 13.00 minutos. Prioridad: 0.585
#   Considerando nodo 263933849 con capacidad 43, distancia 932.78 metros y tiempo 9.00 minutos. Prioridad: 0.571
#   Considerando nodo 3628219077 con capacidad 38, distancia 1815.84 metros y tiempo 22.00 minutos. Prioridad: 0.221
#   Considerando nodo 412528267 con capacidad 20, distancia 442.60 metros y tiempo 4.00 minutos. Prioridad: 0.666
#   Considerando nodo 4042528361 con capacidad 51, distancia 2131.21 metros y tiempo 25.00 minutos. Prioridad: 0.156
#   Considerando nodo 9890955626 con capacidad 63, distancia 1798.35 metros y tiempo 21.00 minutos. Prioridad: 0.311
#   Seleccionado nodo 412528235 con prioridad 0.87, capacidad 94, distancia 515.54 metros y tiempo 5.00 minutos.
# Moviéndose al nodo 412528235 con capacidad 94. Capacidad restante: 9724. Distancia total: 1135.54 metros. Tiempo total: 13.00 minutos.
# [412529888, 412529889, 412528242, 412528235]
#
# Analizando opciones desde el nodo 412528235...
#   Considerando nodo 3903819668 con capacidad 96, distancia 325.56 metros y tiempo 4.00 minutos. Prioridad: 0.994
#   Considerando nodo 412554073 con capacidad 34, distancia 862.54 metros y tiempo 10.00 minutos. Prioridad: 0.521
#   Considerando nodo 412549362 con capacidad 14, distancia 833.45 metros y tiempo 10.00 minutos. Prioridad: 0.471
#   Considerando nodo 412554037 con capacidad 46, distancia 1041.89 metros y tiempo 11.00 minutos. Prioridad: 0.476
#   Considerando nodo 417252102 con capacidad 11, distancia 1040.50 metros y tiempo 12.00 minutos. Prioridad: 0.357
#   Considerando nodo 417252136 con capacidad 51, distancia 1042.05 metros y tiempo 12.00 minutos. Prioridad: 0.478
#   Considerando nodo 1273879842 con capacidad 81, distancia 1499.62 metros y tiempo 14.00 minutos. Prioridad: 0.368
#   Considerando nodo 417252706 con capacidad 88, distancia 853.77 metros y tiempo 10.00 minutos. Prioridad: 0.690
#   Considerando nodo 1841915508 con capacidad 84, distancia 1037.39 metros y tiempo 10.00 minutos. Prioridad: 0.606
#   Considerando nodo 3630229215 con capacidad 36, distancia 749.81 metros y tiempo 8.00 minutos. Prioridad: 0.596
#   Considerando nodo 417251204 con capacidad 41, distancia 739.02 metros y tiempo 8.00 minutos. Prioridad: 0.615
#   Considerando nodo 392151970 con capacidad 5, distancia 1442.78 metros y tiempo 18.00 minutos. Prioridad: 0.107
#   Considerando nodo 391036814 con capacidad 83, distancia 770.63 metros y tiempo 8.00 minutos. Prioridad: 0.732
#   Considerando nodo 412554325 con capacidad 56, distancia 1270.41 metros y tiempo 14.00 minutos. Prioridad: 0.380
#   Considerando nodo 4354022565 con capacidad 47, distancia 1050.31 metros y tiempo 12.00 minutos. Prioridad: 0.463
#   Considerando nodo 4170789705 con capacidad 38, distancia 1025.40 metros y tiempo 11.00 minutos. Prioridad: 0.458
#   Considerando nodo 412529887 con capacidad 26, distancia 778.01 metros y tiempo 10.00 minutos. Prioridad: 0.529
#   Considerando nodo 412557563 con capacidad 39, distancia 911.74 metros y tiempo 12.00 minutos. Prioridad: 0.492
#   Considerando nodo 9890962282 con capacidad 17, distancia 1138.32 metros y tiempo 14.00 minutos. Prioridad: 0.312
#   Considerando nodo 417251195 con capacidad 49, distancia 1441.50 metros y tiempo 17.00 minutos. Prioridad: 0.255
#   Considerando nodo 412554242 con capacidad 9, distancia 945.55 metros y tiempo 11.00 minutos. Prioridad: 0.400
#   Considerando nodo 791159897 con capacidad 59, distancia 1309.58 metros y tiempo 13.00 minutos. Prioridad: 0.387
#   Considerando nodo 326022171 con capacidad 70, distancia 485.87 metros y tiempo 6.00 minutos. Prioridad: 0.827
#   Considerando nodo 417251159 con capacidad 86, distancia 857.62 metros y tiempo 8.00 minutos. Prioridad: 0.707
#   Considerando nodo 417252572 con capacidad 87, distancia 1339.14 metros y tiempo 17.00 minutos. Prioridad: 0.411
#   Considerando nodo 3628169609 con capacidad 77, distancia 1158.79 metros y tiempo 14.00 minutos. Prioridad: 0.488
#   Considerando nodo 412553943 con capacidad 32, distancia 985.90 metros y tiempo 10.00 minutos. Prioridad: 0.467
#   Considerando nodo 412554253 con capacidad 78, distancia 782.52 metros y tiempo 10.00 minutos. Prioridad: 0.687
#   Considerando nodo 4549868556 con capacidad 14, distancia 807.59 metros y tiempo 11.00 minutos. Prioridad: 0.469
#   Considerando nodo 1273664820 con capacidad 51, distancia 912.35 metros y tiempo 9.00 minutos. Prioridad: 0.566
#   Considerando nodo 417252592 con capacidad 16, distancia 1149.65 metros y tiempo 13.00 minutos. Prioridad: 0.317
#   Considerando nodo 515494213 con capacidad 55, distancia 1188.66 metros y tiempo 11.00 minutos. Prioridad: 0.446
#   Considerando nodo 412554319 con capacidad 12, distancia 1172.45 metros y tiempo 13.00 minutos. Prioridad: 0.296
#   Considerando nodo 316625042 con capacidad 21, distancia 983.42 metros y tiempo 11.00 minutos. Prioridad: 0.422
#   Considerando nodo 9890779746 con capacidad 36, distancia 1069.07 metros y tiempo 13.00 minutos. Prioridad: 0.410
#   Considerando nodo 412557570 con capacidad 31, distancia 1176.04 metros y tiempo 12.00 minutos. Prioridad: 0.365
#   Considerando nodo 412557535 con capacidad 44, distancia 911.79 metros y tiempo 11.00 minutos. Prioridad: 0.520
#   Considerando nodo 412528255 con capacidad 45, distancia 654.19 metros y tiempo 7.00 minutos. Prioridad: 0.673
#   Considerando nodo 412528286 con capacidad 76, distancia 535.48 metros y tiempo 5.00 minutos. Prioridad: 0.839
#   Considerando nodo 4351533396 con capacidad 98, distancia 1123.07 metros y tiempo 13.00 minutos. Prioridad: 0.578
#   Considerando nodo 6408227574 con capacidad 66, distancia 503.49 metros y tiempo 8.00 minutos. Prioridad: 0.783
#   Considerando nodo 263933849 con capacidad 43, distancia 1211.36 metros y tiempo 14.00 minutos. Prioridad: 0.363
#   Considerando nodo 3628219077 con capacidad 38, distancia 1300.30 metros y tiempo 17.00 minutos. Prioridad: 0.276
#   Considerando nodo 412528267 con capacidad 20, distancia 450.85 metros y tiempo 7.00 minutos. Prioridad: 0.675
#   Considerando nodo 4042528361 con capacidad 51, distancia 1615.67 metros y tiempo 20.00 minutos. Prioridad: 0.156
#   Considerando nodo 9890955626 con capacidad 63, distancia 1282.81 metros y tiempo 16.00 minutos. Prioridad: 0.372
#   Seleccionado nodo 3903819668 con prioridad 0.99, capacidad 96, distancia 325.56 metros y tiempo 4.00 minutos.
# Moviéndose al nodo 3903819668 con capacidad 96. Capacidad restante: 9628. Distancia total: 1461.09 metros. Tiempo total: 17.00 minutos.
# [412529888, 412529889, 412528242, 412528235, 3903819668]
#
# Analizando opciones desde el nodo 3903819668...
#   Considerando nodo 412554073 con capacidad 34, distancia 1106.60 metros y tiempo 13.00 minutos. Prioridad: 0.407
#   Considerando nodo 412549362 con capacidad 14, distancia 886.16 metros y tiempo 9.00 minutos. Prioridad: 0.456
#   Considerando nodo 412554037 con capacidad 46, distancia 1158.18 metros y tiempo 12.00 minutos. Prioridad: 0.437
#   Considerando nodo 417252102 con capacidad 11, distancia 1142.80 metros y tiempo 15.00 minutos. Prioridad: 0.306
#   Considerando nodo 417252136 con capacidad 51, distancia 862.27 metros y tiempo 13.00 minutos. Prioridad: 0.539
#   Considerando nodo 1273879842 con capacidad 81, distancia 1174.06 metros y tiempo 10.00 minutos. Prioridad: 0.558
#   Considerando nodo 417252706 con capacidad 88, distancia 643.47 metros y tiempo 9.00 minutos. Prioridad: 0.761
#   Considerando nodo 1841915508 con capacidad 84, distancia 711.84 metros y tiempo 6.00 minutos. Prioridad: 0.755
#   Considerando nodo 3630229215 con capacidad 36, distancia 520.23 metros y tiempo 7.00 minutos. Prioridad: 0.661
#   Considerando nodo 417251204 con capacidad 41, distancia 983.08 metros y tiempo 12.00 minutos. Prioridad: 0.478
#   Considerando nodo 392151970 con capacidad 5, distancia 1295.67 metros y tiempo 17.00 minutos. Prioridad: 0.219
#   Considerando nodo 391036814 con capacidad 83, distancia 1014.68 metros y tiempo 11.00 minutos. Prioridad: 0.606
#   Considerando nodo 412554325 con capacidad 56, distancia 1386.70 metros y tiempo 15.00 minutos. Prioridad: 0.365
#   Considerando nodo 4354022565 con capacidad 47, distancia 761.98 metros y tiempo 9.00 minutos. Prioridad: 0.597
#   Considerando nodo 4170789705 con capacidad 38, distancia 878.92 metros y tiempo 14.00 minutos. Prioridad: 0.484
#   Considerando nodo 412529887 con capacidad 26, distancia 489.68 metros y tiempo 7.00 minutos. Prioridad: 0.640
#   Considerando nodo 412557563 con capacidad 39, distancia 1028.03 metros y tiempo 13.00 minutos. Prioridad: 0.448
#   Considerando nodo 9890962282 con capacidad 17, distancia 1240.62 metros y tiempo 17.00 minutos. Prioridad: 0.274
#   Considerando nodo 417251195 con capacidad 49, distancia 1590.79 metros y tiempo 21.00 minutos. Prioridad: 0.220
#   Considerando nodo 412554242 con capacidad 9, distancia 1061.84 metros y tiempo 12.00 minutos. Prioridad: 0.355
#   Considerando nodo 791159897 con capacidad 59, distancia 1518.04 metros y tiempo 14.00 minutos. Prioridad: 0.341
#   Considerando nodo 326022171 con capacidad 70, distancia 197.54 metros y tiempo 3.00 minutos. Prioridad: 0.908
#   Considerando nodo 417251159 con capacidad 86, distancia 1101.67 metros y tiempo 12.00 minutos. Prioridad: 0.578
#   Considerando nodo 417252572 con capacidad 87, distancia 1192.03 metros y tiempo 16.00 minutos. Prioridad: 0.513
#   Considerando nodo 3628169609 con capacidad 77, distancia 1136.95 metros y tiempo 15.00 minutos. Prioridad: 0.510
#   Considerando nodo 412553943 con capacidad 32, distancia 1102.19 metros y tiempo 11.00 minutos. Prioridad: 0.422
#   Considerando nodo 412554253 con capacidad 78, distancia 898.80 metros y tiempo 11.00 minutos. Prioridad: 0.629
#   Considerando nodo 4549868556 con capacidad 14, distancia 519.26 metros y tiempo 8.00 minutos. Prioridad: 0.584
#   Considerando nodo 1273664820 con capacidad 51, distancia 586.80 metros y tiempo 5.00 minutos. Prioridad: 0.704
#   Considerando nodo 417252592 con capacidad 16, distancia 1294.69 metros y tiempo 17.00 minutos. Prioridad: 0.253
#   Considerando nodo 515494213 con capacidad 55, distancia 863.10 metros y tiempo 7.00 minutos. Prioridad: 0.608
#   Considerando nodo 412554319 con capacidad 12, distancia 1288.74 metros y tiempo 14.00 minutos. Prioridad: 0.271
#   Considerando nodo 316625042 con capacidad 21, distancia 1099.71 metros y tiempo 12.00 minutos. Prioridad: 0.379
#   Considerando nodo 9890779746 con capacidad 36, distancia 858.76 metros y tiempo 12.00 minutos. Prioridad: 0.503
#   Considerando nodo 412557570 con capacidad 31, distancia 1292.33 metros y tiempo 13.00 minutos. Prioridad: 0.338
#   Considerando nodo 412557535 con capacidad 44, distancia 1028.07 metros y tiempo 12.00 minutos. Prioridad: 0.473
#   Considerando nodo 412528255 con capacidad 45, distancia 639.73 metros y tiempo 7.00 minutos. Prioridad: 0.650
#   Considerando nodo 412528286 con capacidad 76, distancia 779.54 metros y tiempo 8.00 minutos. Prioridad: 0.690
#   Considerando nodo 4351533396 con capacidad 98, distancia 912.76 metros y tiempo 12.00 minutos. Prioridad: 0.676
#   Considerando nodo 6408227574 con capacidad 66, distancia 177.94 metros y tiempo 4.00 minutos. Prioridad: 0.893
#   Considerando nodo 263933849 con capacidad 43, distancia 1327.65 metros y tiempo 15.00 minutos. Prioridad: 0.344
#   Considerando nodo 3628219077 con capacidad 38, distancia 1230.87 metros y tiempo 17.00 minutos. Prioridad: 0.341
#   Considerando nodo 412528267 con capacidad 20, distancia 563.38 metros y tiempo 8.00 minutos. Prioridad: 0.588
#   Considerando nodo 4042528361 con capacidad 51, distancia 1717.97 metros y tiempo 24.00 minutos. Prioridad: 0.156
#   Considerando nodo 9890955626 con capacidad 63, distancia 1072.50 metros y tiempo 15.00 minutos. Prioridad: 0.488
#   Seleccionado nodo 326022171 con prioridad 0.91, capacidad 70, distancia 197.54 metros y tiempo 3.00 minutos.
# Moviéndose al nodo 326022171 con capacidad 70. Capacidad restante: 9558. Distancia total: 1658.63 metros. Tiempo total: 20.00 minutos.
# [412529888, 412529889, 412528242, 412528235, 3903819668, 326022171]
#
# Analizando opciones desde el nodo 326022171...
#   Considerando nodo 412554073 con capacidad 34, distancia 1128.47 metros y tiempo 12.00 minutos. Prioridad: 0.459
#   Considerando nodo 412549362 con capacidad 14, distancia 688.62 metros y tiempo 6.00 minutos. Prioridad: 0.583
#   Considerando nodo 412554037 con capacidad 46, distancia 985.08 metros y tiempo 10.00 minutos. Prioridad: 0.556
#   Considerando nodo 417252102 con capacidad 11, distancia 1347.45 metros y tiempo 17.00 minutos. Prioridad: 0.278
#   Considerando nodo 417252136 con capacidad 51, distancia 1348.99 metros y tiempo 17.00 minutos. Prioridad: 0.400
#   Considerando nodo 1273879842 con capacidad 81, distancia 1221.07 metros y tiempo 17.00 minutos. Prioridad: 0.530
#   Considerando nodo 417252706 con capacidad 88, distancia 1160.72 metros y tiempo 15.00 minutos. Prioridad: 0.587
#   Considerando nodo 1841915508 con capacidad 84, distancia 1111.59 metros y tiempo 15.00 minutos. Prioridad: 0.590
#   Considerando nodo 3630229215 con capacidad 36, distancia 1056.76 metros y tiempo 13.00 minutos. Prioridad: 0.477
#   Considerando nodo 417251204 con capacidad 41, distancia 1045.97 metros y tiempo 13.00 minutos. Prioridad: 0.496
#   Considerando nodo 392151970 con capacidad 5, distancia 1749.72 metros y tiempo 23.00 minutos. Prioridad: 0.085
#   Considerando nodo 391036814 con capacidad 83, distancia 1077.13 metros y tiempo 11.00 minutos. Prioridad: 0.633
#   Considerando nodo 412554325 con capacidad 56, distancia 1213.59 metros y tiempo 13.00 minutos. Prioridad: 0.492
#   Considerando nodo 4354022565 con capacidad 47, distancia 564.44 metros y tiempo 6.00 minutos. Prioridad: 0.721
#   Considerando nodo 4170789705 con capacidad 38, distancia 1332.34 metros y tiempo 16.00 minutos. Prioridad: 0.374
#   Considerando nodo 412529887 con capacidad 26, distancia 292.14 metros y tiempo 4.00 minutos. Prioridad: 0.756
#   Considerando nodo 412557563 con capacidad 39, distancia 854.92 metros y tiempo 11.00 minutos. Prioridad: 0.565
#   Considerando nodo 9890962282 con capacidad 17, distancia 1445.26 metros y tiempo 19.00 minutos. Prioridad: 0.249
#   Considerando nodo 417251195 con capacidad 49, distancia 1748.45 metros y tiempo 22.00 minutos. Prioridad: 0.229
#   Considerando nodo 412554242 con capacidad 9, distancia 888.73 metros y tiempo 10.00 minutos. Prioridad: 0.472
#   Considerando nodo 791159897 con capacidad 59, distancia 1344.94 metros y tiempo 12.00 minutos. Prioridad: 0.471
#   Considerando nodo 417251159 con capacidad 86, distancia 1164.12 metros y tiempo 13.00 minutos. Prioridad: 0.598
#   Considerando nodo 417252572 con capacidad 87, distancia 1646.08 metros y tiempo 22.00 minutos. Prioridad: 0.376
#   Considerando nodo 3628169609 con capacidad 77, distancia 1465.74 metros y tiempo 19.00 minutos. Prioridad: 0.426
#   Considerando nodo 412553943 con capacidad 32, distancia 929.08 metros y tiempo 9.00 minutos. Prioridad: 0.539
#   Considerando nodo 412554253 con capacidad 78, distancia 725.70 metros y tiempo 9.00 minutos. Prioridad: 0.741
#   Considerando nodo 4549868556 con capacidad 14, distancia 321.72 metros y tiempo 5.00 minutos. Prioridad: 0.701
#   Considerando nodo 1273664820 con capacidad 51, distancia 1219.30 metros y tiempo 14.00 minutos. Prioridad: 0.466
#   Considerando nodo 417252592 con capacidad 16, distancia 1456.60 metros y tiempo 18.00 minutos. Prioridad: 0.251
#   Considerando nodo 515494213 con capacidad 55, distancia 1495.60 metros y tiempo 16.00 minutos. Prioridad: 0.377
#   Considerando nodo 412554319 con capacidad 12, distancia 1115.63 metros y tiempo 12.00 minutos. Prioridad: 0.395
#   Considerando nodo 316625042 con capacidad 21, distancia 926.60 metros y tiempo 10.00 minutos. Prioridad: 0.497
#   Considerando nodo 9890779746 con capacidad 36, distancia 1376.01 metros y tiempo 18.00 minutos. Prioridad: 0.337
#   Considerando nodo 412557570 con capacidad 31, distancia 1119.23 metros y tiempo 11.00 minutos. Prioridad: 0.461
#   Considerando nodo 412557535 con capacidad 44, distancia 854.97 metros y tiempo 10.00 minutos. Prioridad: 0.589
#   Considerando nodo 412528255 con capacidad 45, distancia 442.19 metros y tiempo 4.00 minutos. Prioridad: 0.770
#   Considerando nodo 412528286 con capacidad 76, distancia 841.99 metros y tiempo 9.00 minutos. Prioridad: 0.700
#   Considerando nodo 4351533396 con capacidad 98, distancia 1430.02 metros y tiempo 18.00 minutos. Prioridad: 0.510
#   Considerando nodo 6408227574 con capacidad 66, distancia 810.44 metros y tiempo 13.00 minutos. Prioridad: 0.642
#   Considerando nodo 263933849 con capacidad 43, distancia 1154.54 metros y tiempo 13.00 minutos. Prioridad: 0.469
#   Considerando nodo 3628219077 con capacidad 38, distancia 1607.24 metros y tiempo 22.00 minutos. Prioridad: 0.238
#   Considerando nodo 412528267 con capacidad 20, distancia 365.84 metros y tiempo 6.00 minutos. Prioridad: 0.698
#   Considerando nodo 4042528361 con capacidad 51, distancia 1922.61 metros y tiempo 25.00 minutos. Prioridad: 0.156
#   Considerando nodo 9890955626 con capacidad 63, distancia 1589.75 metros y tiempo 21.00 minutos. Prioridad: 0.328
#   Seleccionado nodo 412528255 con prioridad 0.77, capacidad 45, distancia 442.19 metros y tiempo 4.00 minutos.
# Moviéndose al nodo 412528255 con capacidad 45. Capacidad restante: 9513. Distancia total: 2100.82 metros. Tiempo total: 24.00 minutos.
# [412529888, 412529889, 412528242, 412528235, 3903819668, 326022171, 412528255]
#
# Analizando opciones desde el nodo 412528255...
#   Considerando nodo 412554073 con capacidad 34, distancia 1219.45 metros y tiempo 10.00 minutos. Prioridad: 0.478
#   Considerando nodo 412549362 con capacidad 14, distancia 280.06 metros y tiempo 4.00 minutos. Prioridad: 0.716
#   Considerando nodo 412554037 con capacidad 46, distancia 1076.05 metros y tiempo 8.00 minutos. Prioridad: 0.570
#   Considerando nodo 417252102 con capacidad 11, distancia 1555.03 metros y tiempo 17.00 minutos. Prioridad: 0.256
#   Considerando nodo 417252136 con capacidad 51, distancia 1556.58 metros y tiempo 17.00 minutos. Prioridad: 0.378
#   Considerando nodo 1273879842 con capacidad 81, distancia 1472.38 metros y tiempo 19.00 minutos. Prioridad: 0.474
#   Considerando nodo 417252706 con capacidad 88, distancia 1368.30 metros y tiempo 15.00 minutos. Prioridad: 0.559
#   Considerando nodo 1841915508 con capacidad 84, distancia 1362.90 metros y tiempo 15.00 minutos. Prioridad: 0.548
#   Considerando nodo 3630229215 con capacidad 36, distancia 1264.34 metros y tiempo 13.00 minutos. Prioridad: 0.445
#   Considerando nodo 417251204 con capacidad 41, distancia 1253.55 metros y tiempo 13.00 minutos. Prioridad: 0.463
#   Considerando nodo 392151970 con capacidad 5, distancia 1957.31 metros y tiempo 23.00 minutos. Prioridad: 0.079
#   Considerando nodo 391036814 con capacidad 83, distancia 1168.10 metros y tiempo 9.00 minutos. Prioridad: 0.650
#   Considerando nodo 412554325 con capacidad 56, distancia 1168.80 metros y tiempo 11.00 minutos. Prioridad: 0.549
#   Considerando nodo 4354022565 con capacidad 47, distancia 594.39 metros y tiempo 6.00 minutos. Prioridad: 0.717
#   Considerando nodo 4170789705 con capacidad 38, distancia 1539.92 metros y tiempo 16.00 minutos. Prioridad: 0.352
#   Considerando nodo 412529887 con capacidad 26, distancia 584.62 metros y tiempo 8.00 minutos. Prioridad: 0.637
#   Considerando nodo 412557563 con capacidad 39, distancia 945.90 metros y tiempo 9.00 minutos. Prioridad: 0.574
#   Considerando nodo 9890962282 con capacidad 17, distancia 1652.85 metros y tiempo 19.00 minutos. Prioridad: 0.231
#   Considerando nodo 417251195 con capacidad 49, distancia 1956.03 metros y tiempo 22.00 minutos. Prioridad: 0.223
#   Considerando nodo 412554242 con capacidad 9, distancia 979.70 metros y tiempo 8.00 minutos. Prioridad: 0.482
#   Considerando nodo 791159897 con capacidad 59, distancia 1435.91 metros y tiempo 10.00 minutos. Prioridad: 0.498
#   Considerando nodo 417251159 con capacidad 86, distancia 1255.09 metros y tiempo 12.00 minutos. Prioridad: 0.610
#   Considerando nodo 417252572 con capacidad 87, distancia 1853.67 metros y tiempo 22.00 minutos. Prioridad: 0.366
#   Considerando nodo 3628169609 con capacidad 77, distancia 1673.32 metros y tiempo 19.00 minutos. Prioridad: 0.409
#   Considerando nodo 412553943 con capacidad 32, distancia 1020.06 metros y tiempo 7.00 minutos. Prioridad: 0.551
#   Considerando nodo 412554253 con capacidad 78, distancia 816.67 metros y tiempo 7.00 minutos. Prioridad: 0.745
#   Considerando nodo 4549868556 con capacidad 14, distancia 573.04 metros y tiempo 8.00 minutos. Prioridad: 0.604
#   Considerando nodo 1273664820 con capacidad 51, distancia 1426.88 metros y tiempo 14.00 minutos. Prioridad: 0.440
#   Considerando nodo 417252592 con capacidad 16, distancia 1664.18 metros y tiempo 18.00 minutos. Prioridad: 0.234
#   Considerando nodo 515494213 con capacidad 55, distancia 1703.18 metros y tiempo 16.00 minutos. Prioridad: 0.362
#   Considerando nodo 412554319 con capacidad 12, distancia 1206.60 metros y tiempo 10.00 minutos. Prioridad: 0.414
#   Considerando nodo 316625042 con capacidad 21, distancia 665.94 metros y tiempo 7.00 minutos. Prioridad: 0.610
#   Considerando nodo 9890779746 con capacidad 36, distancia 1583.60 metros y tiempo 18.00 minutos. Prioridad: 0.316
#   Considerando nodo 412557570 con capacidad 31, distancia 1210.20 metros y tiempo 9.00 minutos. Prioridad: 0.480
#   Considerando nodo 412557535 con capacidad 44, distancia 945.94 metros y tiempo 8.00 minutos. Prioridad: 0.598
#   Considerando nodo 412528286 con capacidad 76, distancia 932.96 metros y tiempo 8.00 minutos. Prioridad: 0.699
#   Considerando nodo 4351533396 con capacidad 98, distancia 1637.60 metros y tiempo 18.00 minutos. Prioridad: 0.492
#   Considerando nodo 6408227574 con capacidad 66, distancia 1018.02 metros y tiempo 13.00 minutos. Prioridad: 0.601
#   Considerando nodo 263933849 con capacidad 43, distancia 893.88 metros y tiempo 10.00 minutos. Prioridad: 0.590
#   Considerando nodo 3628219077 con capacidad 38, distancia 1814.83 metros y tiempo 22.00 minutos. Prioridad: 0.226
#   Considerando nodo 412528267 con capacidad 20, distancia 330.05 metros y tiempo 3.00 minutos. Prioridad: 0.731
#   Considerando nodo 4042528361 con capacidad 51, distancia 2130.20 metros y tiempo 25.00 minutos. Prioridad: 0.156
#   Considerando nodo 9890955626 con capacidad 63, distancia 1797.34 metros y tiempo 21.00 minutos. Prioridad: 0.316
#   Seleccionado nodo 412554253 con prioridad 0.75, capacidad 78, distancia 816.67 metros y tiempo 7.00 minutos.
# Moviéndose al nodo 412554253 con capacidad 78. Capacidad restante: 9435. Distancia total: 2917.49 metros. Tiempo total: 31.00 minutos.
# [412529888, 412529889, 412528242, 412528235, 3903819668, 326022171, 412528255, 412554253]
#
# Analizando opciones desde el nodo 412554253...
#   Considerando nodo 412554073 con capacidad 34, distancia 402.78 metros y tiempo 3.00 minutos. Prioridad: 0.729
#   Considerando nodo 412549362 con capacidad 14, distancia 1323.82 metros y tiempo 11.00 minutos. Prioridad: 0.403
#   Considerando nodo 412554037 con capacidad 46, distancia 259.38 metros y tiempo 4.00 minutos. Prioridad: 0.789
#   Considerando nodo 417252102 con capacidad 11, distancia 1731.68 metros y tiempo 18.00 minutos. Prioridad: 0.250
#   Considerando nodo 417252136 con capacidad 51, distancia 1733.23 metros y tiempo 18.00 minutos. Prioridad: 0.372
#   Considerando nodo 1273879842 con capacidad 81, distancia 2430.91 metros y tiempo 24.00 minutos. Prioridad: 0.264
#   Considerando nodo 417252706 con capacidad 88, distancia 1580.10 metros y tiempo 16.00 minutos. Prioridad: 0.534
#   Considerando nodo 1841915508 con capacidad 84, distancia 2145.24 metros y tiempo 20.00 minutos. Prioridad: 0.367
#   Considerando nodo 3630229215 con capacidad 36, distancia 1476.13 metros y tiempo 14.00 minutos. Prioridad: 0.414
#   Considerando nodo 417251204 con capacidad 41, distancia 1418.44 metros y tiempo 14.00 minutos. Prioridad: 0.441
#   Considerando nodo 392151970 con capacidad 5, distancia 2133.96 metros y tiempo 24.00 minutos. Prioridad: 0.096
#   Considerando nodo 391036814 con capacidad 83, distancia 686.20 metros y tiempo 8.00 minutos. Prioridad: 0.777
#   Considerando nodo 412554325 con capacidad 56, distancia 727.17 metros y tiempo 9.00 minutos. Prioridad: 0.678
#   Considerando nodo 4354022565 con capacidad 47, distancia 1623.04 metros y tiempo 13.00 minutos. Prioridad: 0.423
#   Considerando nodo 4170789705 con capacidad 38, distancia 1716.58 metros y tiempo 17.00 minutos. Prioridad: 0.344
#   Considerando nodo 412529887 con capacidad 26, distancia 1501.98 metros y tiempo 15.00 minutos. Prioridad: 0.369
#   Considerando nodo 412557563 con capacidad 39, distancia 129.23 metros y tiempo 2.00 minutos. Prioridad: 0.811
#   Considerando nodo 9890962282 con capacidad 17, distancia 1829.50 metros y tiempo 20.00 minutos. Prioridad: 0.231
#   Considerando nodo 417251195 con capacidad 49, distancia 2132.69 metros y tiempo 23.00 minutos. Prioridad: 0.239
#   Considerando nodo 412554242 con capacidad 9, distancia 163.03 metros y tiempo 1.00 minutos. Prioridad: 0.720
#   Considerando nodo 791159897 con capacidad 59, distancia 619.24 metros y tiempo 7.00 minutos. Prioridad: 0.726
#   Considerando nodo 417251159 con capacidad 86, distancia 1164.13 metros y tiempo 12.00 minutos. Prioridad: 0.650
#   Considerando nodo 417252572 con capacidad 87, distancia 2030.32 metros y tiempo 23.00 minutos. Prioridad: 0.377
#   Considerando nodo 3628169609 con capacidad 77, distancia 1849.97 metros y tiempo 20.00 minutos. Prioridad: 0.410
#   Considerando nodo 412553943 con capacidad 32, distancia 328.24 metros y tiempo 5.00 minutos. Prioridad: 0.723
#   Considerando nodo 4549868556 con capacidad 14, distancia 1531.57 metros y tiempo 15.00 minutos. Prioridad: 0.326
#   Considerando nodo 1273664820 con capacidad 51, distancia 1668.38 metros y tiempo 16.00 minutos. Prioridad: 0.402
#   Considerando nodo 417252592 con capacidad 16, distancia 1840.84 metros y tiempo 19.00 minutos. Prioridad: 0.233
#   Considerando nodo 515494213 con capacidad 55, distancia 1977.22 metros y tiempo 20.00 minutos. Prioridad: 0.315
#   Considerando nodo 412554319 con capacidad 12, distancia 778.95 metros y tiempo 8.00 minutos. Prioridad: 0.540
#   Considerando nodo 316625042 con capacidad 21, distancia 805.14 metros y tiempo 6.00 minutos. Prioridad: 0.577
#   Considerando nodo 9890779746 con capacidad 36, distancia 1795.39 metros y tiempo 19.00 minutos. Prioridad: 0.304
#   Considerando nodo 412557570 con capacidad 31, distancia 393.53 metros y tiempo 6.00 minutos. Prioridad: 0.697
#   Considerando nodo 412557535 con capacidad 44, distancia 681.75 metros y tiempo 6.00 minutos. Prioridad: 0.675
#   Considerando nodo 412528286 con capacidad 76, distancia 861.32 metros y tiempo 8.00 minutos. Prioridad: 0.718
#   Considerando nodo 4351533396 con capacidad 98, distancia 1849.39 metros y tiempo 19.00 minutos. Prioridad: 0.482
#   Considerando nodo 6408227574 con capacidad 66, distancia 1611.34 metros y tiempo 16.00 minutos. Prioridad: 0.460
#   Considerando nodo 263933849 con capacidad 43, distancia 1033.07 metros y tiempo 9.00 minutos. Prioridad: 0.571
#   Considerando nodo 3628219077 con capacidad 38, distancia 1991.48 metros y tiempo 23.00 minutos. Prioridad: 0.236
#   Considerando nodo 412528267 con capacidad 20, distancia 826.09 metros y tiempo 8.00 minutos. Prioridad: 0.554
#   Considerando nodo 4042528361 con capacidad 51, distancia 2306.85 metros y tiempo 26.00 minutos. Prioridad: 0.183
#   Considerando nodo 9890955626 con capacidad 63, distancia 1986.98 metros y tiempo 22.00 minutos. Prioridad: 0.321
#   Seleccionado nodo 412557563 con prioridad 0.81, capacidad 39, distancia 129.23 metros y tiempo 2.00 minutos.
# Moviéndose al nodo 412557563 con capacidad 39. Capacidad restante: 9396. Distancia total: 3046.72 metros. Tiempo total: 33.00 minutos.
# [412529888, 412529889, 412528242, 412528235, 3903819668, 326022171, 412528255, 412554253, 412557563]
#
# Analizando opciones desde el nodo 412557563...
#   Considerando nodo 412554073 con capacidad 34, distancia 508.96 metros y tiempo 5.00 minutos. Prioridad: 0.698
#   Considerando nodo 412549362 con capacidad 14, distancia 1398.33 metros y tiempo 13.00 minutos. Prioridad: 0.382
#   Considerando nodo 412554037 con capacidad 46, distancia 130.15 metros y tiempo 2.00 minutos. Prioridad: 0.841
#   Considerando nodo 417252102 con capacidad 11, distancia 1714.67 metros y tiempo 18.00 minutos. Prioridad: 0.264
#   Considerando nodo 417252136 con capacidad 51, distancia 1716.22 metros y tiempo 18.00 minutos. Prioridad: 0.386
#   Considerando nodo 1273879842 con capacidad 81, distancia 2484.86 metros y tiempo 24.00 minutos. Prioridad: 0.265
#   Considerando nodo 417252706 con capacidad 88, distancia 1563.09 metros y tiempo 16.00 minutos. Prioridad: 0.548
#   Considerando nodo 1841915508 con capacidad 84, distancia 2174.59 metros y tiempo 20.00 minutos. Prioridad: 0.373
#   Considerando nodo 3630229215 con capacidad 36, distancia 1459.12 metros y tiempo 14.00 minutos. Prioridad: 0.428
#   Considerando nodo 417251204 con capacidad 41, distancia 1401.42 metros y tiempo 14.00 minutos. Prioridad: 0.455
#   Considerando nodo 392151970 con capacidad 5, distancia 2116.95 metros y tiempo 24.00 minutos. Prioridad: 0.110
#   Considerando nodo 391036814 con capacidad 83, distancia 669.19 metros y tiempo 8.00 minutos. Prioridad: 0.789
#   Considerando nodo 412554325 con capacidad 56, distancia 597.95 metros y tiempo 7.00 minutos. Prioridad: 0.730
#   Considerando nodo 4354022565 con capacidad 47, distancia 1697.54 metros y tiempo 15.00 minutos. Prioridad: 0.403
#   Considerando nodo 4170789705 con capacidad 38, distancia 1699.57 metros y tiempo 17.00 minutos. Prioridad: 0.358
#   Considerando nodo 412529887 con capacidad 26, distancia 1576.49 metros y tiempo 17.00 minutos. Prioridad: 0.347
#   Considerando nodo 9890962282 con capacidad 17, distancia 1812.49 metros y tiempo 20.00 minutos. Prioridad: 0.245
#   Considerando nodo 417251195 con capacidad 49, distancia 2115.67 metros y tiempo 23.00 minutos. Prioridad: 0.253
#   Considerando nodo 412554242 con capacidad 9, distancia 276.32 metros y tiempo 3.00 minutos. Prioridad: 0.688
#   Considerando nodo 791159897 con capacidad 59, distancia 490.01 metros y tiempo 5.00 minutos. Prioridad: 0.779
#   Considerando nodo 417251159 con capacidad 86, distancia 1147.12 metros y tiempo 12.00 minutos. Prioridad: 0.664
#   Considerando nodo 417252572 con capacidad 87, distancia 2013.31 metros y tiempo 23.00 minutos. Prioridad: 0.391
#   Considerando nodo 3628169609 con capacidad 77, distancia 1832.96 metros y tiempo 20.00 minutos. Prioridad: 0.424
#   Considerando nodo 412553943 con capacidad 32, distancia 199.01 metros y tiempo 3.00 minutos. Prioridad: 0.775
#   Considerando nodo 4549868556 con capacidad 14, distancia 1606.07 metros y tiempo 17.00 minutos. Prioridad: 0.304
#   Considerando nodo 1273664820 con capacidad 51, distancia 1651.37 metros y tiempo 16.00 minutos. Prioridad: 0.416
# ...
#
# Analizando opciones desde el nodo 528535487...
#   Considerando nodo 791160064 con capacidad 51, distancia 699.36 metros y tiempo 8.00 minutos. Prioridad: 0.710
#   Considerando nodo 1641248429 con capacidad 20, distancia 258.58 metros y tiempo 3.00 minutos. Prioridad: 0.725
#   Considerando nodo 1641249725 con capacidad 8, distancia 306.29 metros y tiempo 4.00 minutos. Prioridad: 0.672
#   Considerando nodo 4038977441 con capacidad 70, distancia 623.93 metros y tiempo 9.00 minutos. Prioridad: 0.775
#   Considerando nodo 315562687 con capacidad 49, distancia 949.15 metros y tiempo 12.00 minutos. Prioridad: 0.632
#   Considerando nodo 1641248361 con capacidad 27, distancia 383.21 metros y tiempo 4.00 minutos. Prioridad: 0.718
#   Considerando nodo 4376219517 con capacidad 70, distancia 575.32 metros y tiempo 8.00 minutos. Prioridad: 0.791
#   Considerando nodo 1903604993 con capacidad 11, distancia 885.58 metros y tiempo 10.00 minutos. Prioridad: 0.538
#   Considerando nodo 1641248398 con capacidad 5, distancia 377.69 metros y tiempo 5.00 minutos. Prioridad: 0.643
#   Considerando nodo 1641248356 con capacidad 6, distancia 100.82 metros y tiempo 2.00 minutos. Prioridad: 0.716
#   Considerando nodo 791159857 con capacidad 33, distancia 475.16 metros y tiempo 5.00 minutos. Prioridad: 0.714
#   Seleccionado nodo 4376219517 con prioridad 0.79, capacidad 70, distancia 575.32 metros y tiempo 8.00 minutos.
# Moviéndose al nodo 4376219517 con capacidad 70. Capacidad restante: 8485. Distancia total: 13298.96 metros. Tiempo total: 167.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517]
#
# Analizando opciones desde el nodo 4376219517...
#   Considerando nodo 791160064 con capacidad 51, distancia 1433.37 metros y tiempo 13.00 minutos. Prioridad: 0.481
#   Considerando nodo 1641248429 con capacidad 20, distancia 665.60 metros y tiempo 4.00 minutos. Prioridad: 0.613
#   Considerando nodo 1641249725 con capacidad 8, distancia 1040.30 metros y tiempo 8.00 minutos. Prioridad: 0.468
#   Considerando nodo 4038977441 con capacidad 70, distancia 48.61 metros y tiempo 1.00 minutos. Prioridad: 0.916
#   Considerando nodo 315562687 con capacidad 49, distancia 373.83 metros y tiempo 4.00 minutos. Prioridad: 0.760
#   Considerando nodo 1641248361 con capacidad 27, distancia 673.71 metros y tiempo 6.00 minutos. Prioridad: 0.616
#   Considerando nodo 1903604993 con capacidad 11, distancia 1479.85 metros y tiempo 15.00 minutos. Prioridad: 0.329
#   Considerando nodo 1641248398 con capacidad 5, distancia 474.93 metros y tiempo 3.00 minutos. Prioridad: 0.612
#   Considerando nodo 1641248356 con capacidad 6, distancia 834.83 metros y tiempo 7.00 minutos. Prioridad: 0.510
#   Considerando nodo 791159857 con capacidad 33, distancia 1209.17 metros y tiempo 10.00 minutos. Prioridad: 0.495
#   Seleccionado nodo 4038977441 con prioridad 0.92, capacidad 70, distancia 48.61 metros y tiempo 1.00 minutos.
# Moviéndose al nodo 4038977441 con capacidad 70. Capacidad restante: 8415. Distancia total: 13347.57 metros. Tiempo total: 168.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441]
#
# Analizando opciones desde el nodo 4038977441...
#   Considerando nodo 791160064 con capacidad 51, distancia 1445.70 metros y tiempo 13.00 minutos. Prioridad: 0.505
#   Considerando nodo 1641248429 con capacidad 20, distancia 655.96 metros y tiempo 6.00 minutos. Prioridad: 0.655
#   Considerando nodo 1641249725 con capacidad 8, distancia 1051.80 metros y tiempo 8.00 minutos. Prioridad: 0.510
#   Considerando nodo 315562687 con capacidad 49, distancia 325.21 metros y tiempo 3.00 minutos. Prioridad: 0.850
#   Considerando nodo 1641248361 con capacidad 27, distancia 873.80 metros y tiempo 10.00 minutos. Prioridad: 0.587
#   Considerando nodo 1903604993 con capacidad 11, distancia 1656.33 metros y tiempo 15.00 minutos. Prioridad: 0.312
#   Considerando nodo 1641248398 con capacidad 5, distancia 782.81 metros y tiempo 9.00 minutos. Prioridad: 0.549
#   Considerando nodo 1641248356 con capacidad 6, distancia 871.56 metros y tiempo 9.00 minutos. Prioridad: 0.532
#   Considerando nodo 791159857 con capacidad 33, distancia 1245.91 metros y tiempo 10.00 minutos. Prioridad: 0.524
#   Seleccionado nodo 315562687 con prioridad 0.85, capacidad 49, distancia 325.21 metros y tiempo 3.00 minutos.
# Moviéndose al nodo 315562687 con capacidad 49. Capacidad restante: 8366. Distancia total: 13672.78 metros. Tiempo total: 171.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687]
#
# Analizando opciones desde el nodo 315562687...
#   Considerando nodo 791160064 con capacidad 51, distancia 3094.98 metros y tiempo 27.00 minutos. Prioridad: 0.443
#   Considerando nodo 1641248429 con capacidad 20, distancia 3875.83 metros y tiempo 36.00 minutos. Prioridad: 0.159
#   Considerando nodo 1641249725 con capacidad 8, distancia 3489.15 metros y tiempo 31.00 minutos. Prioridad: 0.218
#   Considerando nodo 1641248361 con capacidad 27, distancia 4000.47 metros y tiempo 37.00 minutos. Prioridad: 0.153
#   Considerando nodo 1903604993 con capacidad 11, distancia 3361.18 metros y tiempo 31.00 minutos. Prioridad: 0.248
#   Considerando nodo 1641248398 con capacidad 5, distancia 3994.94 metros y tiempo 38.00 minutos. Prioridad: 0.079
#   Considerando nodo 1641248356 con capacidad 6, distancia 3718.07 metros y tiempo 35.00 minutos. Prioridad: 0.148
#   Considerando nodo 791159857 con capacidad 33, distancia 3318.50 metros y tiempo 31.00 minutos. Prioridad: 0.324
#   Seleccionado nodo 791160064 con prioridad 0.44, capacidad 51, distancia 3094.98 metros y tiempo 27.00 minutos.
# Moviéndose al nodo 791160064 con capacidad 51. Capacidad restante: 8315. Distancia total: 16767.76 metros. Tiempo total: 198.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064]
#
# Analizando opciones desde el nodo 791160064...
#   Considerando nodo 1641248429 con capacidad 20, distancia 780.85 metros y tiempo 9.00 minutos. Prioridad: 0.597
#   Considerando nodo 1641249725 con capacidad 8, distancia 394.17 metros y tiempo 4.00 minutos. Prioridad: 0.686
#   Considerando nodo 1641248361 con capacidad 27, distancia 905.48 metros y tiempo 10.00 minutos. Prioridad: 0.583
#   Considerando nodo 1903604993 con capacidad 11, distancia 266.20 metros y tiempo 4.00 minutos. Prioridad: 0.722
#   Considerando nodo 1641248398 con capacidad 5, distancia 899.96 metros y tiempo 11.00 minutos. Prioridad: 0.506
#   Considerando nodo 1641248356 con capacidad 6, distancia 623.09 metros y tiempo 8.00 minutos. Prioridad: 0.595
#   Considerando nodo 791159857 con capacidad 33, distancia 223.52 metros y tiempo 4.00 minutos. Prioridad: 0.800
#   Seleccionado nodo 791159857 con prioridad 0.80, capacidad 33, distancia 223.52 metros y tiempo 4.00 minutos.
# Moviéndose al nodo 791159857 con capacidad 33. Capacidad restante: 8282. Distancia total: 16991.28 metros. Tiempo total: 202.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857]
#
# Analizando opciones desde el nodo 791159857...
#   Considerando nodo 1641248429 con capacidad 20, distancia 612.77 metros y tiempo 9.00 minutos. Prioridad: 0.629
#   Considerando nodo 1641249725 con capacidad 8, distancia 226.09 metros y tiempo 4.00 minutos. Prioridad: 0.704
#   Considerando nodo 1641248361 con capacidad 27, distancia 733.02 metros y tiempo 10.00 minutos. Prioridad: 0.620
#   Considerando nodo 1903604993 con capacidad 11, distancia 426.21 metros y tiempo 5.00 minutos. Prioridad: 0.668
#   Considerando nodo 1641248398 con capacidad 5, distancia 731.87 metros y tiempo 11.00 minutos. Prioridad: 0.544
#   Considerando nodo 1641248356 con capacidad 6, distancia 455.01 metros y tiempo 8.00 minutos. Prioridad: 0.623
#   Seleccionado nodo 1641249725 con prioridad 0.70, capacidad 8, distancia 226.09 metros y tiempo 4.00 minutos.
# Moviéndose al nodo 1641249725 con capacidad 8. Capacidad restante: 8274. Distancia total: 17217.37 metros. Tiempo total: 206.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857, 1641249725]
#
# Analizando opciones desde el nodo 1641249725...
#   Considerando nodo 1641248429 con capacidad 20, distancia 386.68 metros y tiempo 5.00 minutos. Prioridad: 0.691
#   Considerando nodo 1641248361 con capacidad 27, distancia 511.31 metros y tiempo 6.00 minutos. Prioridad: 0.683
#   Considerando nodo 1903604993 con capacidad 11, distancia 627.83 metros y tiempo 7.00 minutos. Prioridad: 0.605
#   Considerando nodo 1641248398 con capacidad 5, distancia 505.79 metros y tiempo 7.00 minutos. Prioridad: 0.607
#   Considerando nodo 1641248356 con capacidad 6, distancia 228.92 metros y tiempo 4.00 minutos. Prioridad: 0.682
#   Seleccionado nodo 1641248429 con prioridad 0.69, capacidad 20, distancia 386.68 metros y tiempo 5.00 minutos.
# Moviéndose al nodo 1641248429 con capacidad 20. Capacidad restante: 8254. Distancia total: 17604.05 metros. Tiempo total: 211.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857, 1641249725, 1641248429]
#
# Analizando opciones desde el nodo 1641248429...
#   Considerando nodo 1641248361 con capacidad 27, distancia 495.29 metros y tiempo 5.00 minutos. Prioridad: 0.710
#   Considerando nodo 1903604993 con capacidad 11, distancia 1010.98 metros y tiempo 11.00 minutos. Prioridad: 0.523
#   Considerando nodo 1641248398 con capacidad 5, distancia 452.37 metros y tiempo 6.00 minutos. Prioridad: 0.642
#   Considerando nodo 1641248356 con capacidad 6, distancia 226.21 metros y tiempo 3.00 minutos. Prioridad: 0.708
#   Seleccionado nodo 1641248361 con prioridad 0.71, capacidad 27, distancia 495.29 metros y tiempo 5.00 minutos.
# Moviéndose al nodo 1641248361 con capacidad 27. Capacidad restante: 8227. Distancia total: 18099.34 metros. Tiempo total: 216.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857, 1641249725, 1641248429, 1641248361]
#
# Analizando opciones desde el nodo 1641248361...
#   Considerando nodo 1903604993 con capacidad 11, distancia 814.39 metros y tiempo 10.00 minutos. Prioridad: 0.545
#   Considerando nodo 1641248398 con capacidad 5, distancia 212.82 metros y tiempo 3.00 minutos. Prioridad: 0.686
#   Considerando nodo 1641248356 con capacidad 6, distancia 161.12 metros y tiempo 2.00 minutos. Prioridad: 0.706
#   Seleccionado nodo 1641248356 con prioridad 0.71, capacidad 6, distancia 161.12 metros y tiempo 2.00 minutos.
# Moviéndose al nodo 1641248356 con capacidad 6. Capacidad restante: 8221. Distancia total: 18260.45 metros. Tiempo total: 218.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857, 1641249725, 1641248429, 1641248361, 1641248356]
#
# Analizando opciones desde el nodo 1641248356...
#   Considerando nodo 1903604993 con capacidad 11, distancia 784.77 metros y tiempo 8.00 minutos. Prioridad: 0.572
#   Considerando nodo 1641248398 con capacidad 5, distancia 557.07 metros y tiempo 8.00 minutos. Prioridad: 0.593
#   Seleccionado nodo 1641248398 con prioridad 0.59, capacidad 5, distancia 557.07 metros y tiempo 8.00 minutos.
# Moviéndose al nodo 1641248398 con capacidad 5. Capacidad restante: 8216. Distancia total: 18817.52 metros. Tiempo total: 226.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857, 1641249725, 1641248429, 1641248361, 1641248356, 1641248398]
#
# Analizando opciones desde el nodo 1641248398...
#   Considerando nodo 1903604993 con capacidad 11, distancia 1004.92 metros y tiempo 13.00 minutos. Prioridad: 0.482
#   Seleccionado nodo 1903604993 con prioridad 0.48, capacidad 11, distancia 1004.92 metros y tiempo 13.00 minutos.
# Moviéndose al nodo 1903604993 con capacidad 11. Capacidad restante: 8205. Distancia total: 19822.45 metros. Tiempo total: 239.00 minutos.
# [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857, 1641249725, 1641248429, 1641248361, 1641248356, 1641248398, 1903604993]
#
# Analizando opciones desde el nodo 1903604993...
#   No hay más nodos disponibles para visitar o todos exceden la capacidad restante del camión.
# No hay más nodos disponibles para visitar o todos exceden la capacidad restante del camión. Finalizando recorrido.
# Regresando al nodo 182472511 desde el nodo 1903604993. Distancia de regreso: 1701.97 metros. Tiempo de regreso: 15.00 minutos.
#
# Recorrido completo: [182472511, 416958445, 416660482, 416660454, 416660505, 416966089, 8917264952, 417247858, 417247888, 11346851849, 391038435, 417248118, 11346851831, 391038300, 392148910, 416966263, 416966189, 417247859, 416953778, 416953794, 416660444, 1903604976, 1641288951, 1641288949, 1641248389, 7571671029, 1641297815, 528535487, 4376219517, 4038977441, 315562687, 791160064, 791159857, 1641249725, 1641248429, 1641248361, 1641248356, 1641248398, 1903604993]
# Distancia total recorrida: 21524.42 metros
# Tiempo total: 254.00 minutos
